# %%
from utils.vector import DynamicVector
from algorithm import sort

var tall: DynamicVector[Int] = DynamicVector[Int]()
#var ord = DynamicVector[String]() vanskelig
tall.push_back(3) # 10/10 code
tall.push_back(1)
tall.push_back(2)
tall.push_back(6)
tall.push_back(8)
tall.push_back(2)
tall.push_back(7)
tall.push_back(7)
tall.push_back(6)
tall.push_back(8)
tall.push_back(2)
tall.push_back(7)
tall.push_back(5)
tall.push_back(8)
tall.push_back(6)
tall.push_back(3)
tall.push_back(5)
tall.push_back(4)
tall.push_back(1)
tall.push_back(6)

# antall forekomster av 7
var count: Int = 0
for i in range(tall.size):
    if tall[i] == 7:
        count += 1

print(count)

# antall forekomster av intervalet [2,5]
count = 0
for i in range(len(tall)):
    if 2 <= tall[i] <= 5:
        count += 1

print(count)
# Out:
# 3
# 8

# %%
var tall: DynamicVector[Int] = DynamicVector[Int]()
tall.push_back(89)
tall.push_back(3)
tall.push_back(89)
tall.push_back(87)
tall.push_back(46)
tall.push_back(63)
tall.push_back(54)
tall.push_back(68)
tall.push_back(15)
tall.push_back(69)
tall.push_back(27)
tall.push_back(20)
tall.push_back(68)
tall.push_back(62)
tall.push_back(25)
tall.push_back(26)
tall.push_back(74)
tall.push_back(19)
tall.push_back(96)
tall.push_back(85)
tall.push_back(56)
tall.push_back(88)
tall.push_back(98)
tall.push_back(87)
tall.push_back(1)
tall.push_back(78)
tall.push_back(24)
tall.push_back(64)
tall.push_back(64)
tall.push_back(39)
tall.push_back(14)
tall.push_back(9)
tall.push_back(1)
tall.push_back(30)
tall.push_back(18)
tall.push_back(82)
tall.push_back(41)
tall.push_back(52)
tall.push_back(77)
tall.push_back(81)

sort.sort(tall)

# det største tallet i listen
print(tall[len(tall) - 1])

# det minste tallet i listen
print(tall[0])

# det nest største tallet i listen
print(tall[len(tall) - 2])

# det nest minste tallet i listen
print(tall[1])
# Out:
# 98
# 1
# 96
# 1

# %%
var tall3: DynamicVector[Int] = DynamicVector[Int]()
tall3.push_back(7)
tall3.push_back(24)
tall3.push_back(10)
tall3.push_back(26)
tall3.push_back(35)
tall3.push_back(10)
tall3.push_back(29)
tall3.push_back(2)
tall3.push_back(29)
tall3.push_back(29)
tall3.push_back(40)
tall3.push_back(40)
tall3.push_back(26)
tall3.push_back(16)
tall3.push_back(8)
tall3.push_back(9)
tall3.push_back(26)
tall3.push_back(5)
tall3.push_back(18)
tall3.push_back(9)
tall3.push_back(13)
tall3.push_back(40)
tall3.push_back(28)
tall3.push_back(37)
tall3.push_back(32)
tall3.push_back(6)
tall3.push_back(11)
tall3.push_back(35)
tall3.push_back(9)
tall3.push_back(26)
tall3.push_back(6)
tall3.push_back(11)
tall3.push_back(2)
tall3.push_back(10)
tall3.push_back(11)
tall3.push_back(27)
tall3.push_back(4)
tall3.push_back(8)
tall3.push_back(22)
tall3.push_back(40)
tall3.push_back(19)

var tall4: DynamicVector[Int] = DynamicVector[Int]()
tall4.push_back(56)
tall4.push_back(49)
tall4.push_back(28)
tall4.push_back(52)
tall4.push_back(58)
tall4.push_back(33)
tall4.push_back(26)
tall4.push_back(27)
tall4.push_back(58)
tall4.push_back(36)
tall4.push_back(36)
tall4.push_back(48)
tall4.push_back(55)
tall4.push_back(25)
tall4.push_back(58)
tall4.push_back(57)
tall4.push_back(30)
tall4.push_back(27)
tall4.push_back(36)
tall4.push_back(39)
tall4.push_back(39)
tall4.push_back(58)
tall4.push_back(28)
tall4.push_back(56)
tall4.push_back(52)
tall4.push_back(21)
tall4.push_back(39)
tall4.push_back(22)
tall4.push_back(27)
tall4.push_back(48)
tall4.push_back(37)
tall4.push_back(20)
tall4.push_back(32)
tall4.push_back(38)
tall4.push_back(31)
tall4.push_back(25)
tall4.push_back(42)
tall4.push_back(54)

# fjerner duplikater fra listene
var found: Bool = False
var unik1: DynamicVector[Int] = DynamicVector[Int]()
for i in range(len(tall3)):
    found = False
    for k in range(len(unik1)):
        if tall3[i] == unik1[k]:
            found = True
            break
    if not found:
        unik1.push_back(tall3[i])

var unik2: DynamicVector[Int] = DynamicVector[Int]()
for i in range(len(tall4)):
    found = False
    for k in range(len(unik2)):
        if tall4[i] == unik2[k]:
            found = True
            break
    if not found:
        unik2.push_back(tall4[i])

for i in range(len(unik1)):
    print(unik1[i])

print()

for i in range(len(unik2)):
    print(unik2[i])

# finner tallene som finnes i begge listene
var felles: DynamicVector[Int] = DynamicVector[Int]()
for i in range(len(unik1)):
    for k in range(len(unik2)):
        if unik1[i] == unik2[k]:
            felles.push_back(unik1[i])

print()

for i in range(len(felles)):
    print(felles[i])

# finner tallene som ikke finnes i begge listene
var unike: DynamicVector[Int] = DynamicVector[Int]()
for i in range(len(unik1) + len(unik2)):
    found = False
    for k in range(len(felles)):
        if (unik1[i] if i <= len(unik1) else unik2[i - len(unik1)]) == felles[k]:
            found = True
            break
    if not found:
        unike.push_back(unik1[i] if i <= len(unik1) else unik2[i - len(unik1)])

print()

for i in range(len(unike)):
    print(unike[i])
# Out:
# 7
# 24
# 10
# 26
# 35
# 29
# 2
# 40
# 16
# 8
# 9
# 5
# 18
# 13
# 28
# 37
# 32
# 6
# 11
# 27
# 4
# 22
# 19
#
# 56
# 49
# 28
# 52
# 58
# 33
# 26
# 27
# 36
# 48
# 55
# 25
# 57
# 30
# 39
# 21
# 22
# 37
# 20
# 32
# 38
# 31
# 42
# 54
#
# 26
# 28
# 37
# 32
# 27
# 22
#
# 7
# 24
# 10
# 35
# 29
# 2
# 40
# 16
# 8
# 9
# 5
# 18
# 13
# 6
# 11
# 4
# 19
# 56
# 49
# 52
# 58
# 33
# 36
# 48
# 55
# 25
# 57
# 30
# 39
# 21
# 20
# 38
# 31
# 42
# 54
