# %%
import matplotlib.pyplot as plt
import numpy as np

def woble(x, y):
    d = np.sqrt(x**2 + y**2)
    return np.sin(d)/d

ax = plt.axes(projection='3d')
lin = np.linspace(-3*np.pi, 3*np.pi, 500)
x, y = np.meshgrid(lin,lin)
z = woble(x,y)

ax.plot_surface(x,y,z, cmap=plt.cm.YlGnBu_r)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
wingSize = 0.35
circlesAmount=4
def wing(t):
    t = np.deg2rad(t)

    circle = wingSize * np.e**np.cos(t)
    radius = circle - np.cos(circlesAmount * t)

    x = np.sin(t) * radius
    y = np.cos(t) * radius

    return x,y

t = np.linspace(0,360,180)
x, y = wing(t)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

wingSize = 0.35
circlesAmount=4
def wing(t, r):
    t = np.deg2rad(t)
    r = np.deg2rad(r)

    circle = wingSize * np.e**np.cos(t)
    radius = (circle - np.cos(circlesAmount * t)) * np.sin(r*circlesAmount)

    x = np.sin(t) * radius * np.cos(r)
    z = np.cos(t) * radius
    y = np.sin(r) * radius

    return x,y,z

t, r = np.meshgrid(np.linspace(0,360,180), np.linspace(0,360,180))
x, y, z = wing(t, r)
ax = plt.axes(projection='3d')
ax.plot_surface(x,y,z)
plt.show()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
